# %%
import nltk

# %%
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# True

# %%
def gender_features(word):
  return {'last_name': word[-1]}
gender_features('obama')
# Out:
# {'last_name': 'a'}

# %%
from nltk.corpus import names
names.words()
print(len(names.words()))
# Out:
# 7944

# %%
labeled_names = ([(name,'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])

# %%
print(labeled_names)
# Out:
# [('Sada', 'female'), ('Mayor', 'male'), ('Garold', 'male'), ('Rasia', 'female'), ('Wake', 'male'), ('Lyndsey', 'female'), ('Shilpa', 'female'), ('Fidel', 'male'), ('Jessica', 'female'), ('Fredrick', 'male'), ('Hanny', 'female'), ('Si', 'male'), ('Gussie', 'female'), ('Sari', 'female'), ('Holly', 'female'), ('Peggy', 'female'), ('Sayres', 'male'), ('Zuzana', 'female'), ('Gustave', 'male'), ('Suki', 'female'), ('Zak', 'male'), ('Drea', 'female'), ('Jobye', 'female'), ('Blakeley', 'female'), ('Althea', 'female'), ('Christie', 'female'), ('Nonah', 'female'), ('Odilia', 'female'), ('Hedda', 'female'), ('Fredelia', 'female'), ('Ertha', 'female'), ('Trescha', 'female'), ('Shalom', 'male'), ('Aldric', 'male'), ('Marilyn', 'female'), ('Gillan', 'female'), ('Gratiana', 'female'), ('Antonio', 'male'), ('Fernandina', 'female'), ('Ella', 'female'), ('Eliot', 'male'), ('Herbert', 'male'), ('Bryan', 'male'), ('Wilie', 'female'), ('Hymie', 'male'), ('Vicky', 'female'), ('Remus', 'male'), ('Sussi', 'female'), ('Tally', 'male'), ('Agata', 'female'), ('Wat', 'male'), ('Mustafa', 'male'), ('Bartolomei', 'male'), ('Vibhu', 'male'), ('Elton', 'male'), ('Davie', 'male'), ('Gael', 'female'), ('Kara', 'female'), ('Aube', 'male'), ('Lola', 'female'), ('Michaela', 'female'), ('Crissie', 'female'), ('Wood', 'male'), ('Conway', 'male'), ('Zita', 'female'), ('Hanford', 'male'), ('Mellisa', 'female'), ('Mauritz', 'male'), ('Daniel', 'male'), ('Bertha', 'female'), ('Oberon', 'male'), ('Adria', 'female'), ('Erwin', 'male'), ('Paddie', 'male'), ('Reeva', 'female'), ('Forest', 'male'), ('Riane', 'female'), ('Rebekkah', 'female'), ('Meg', 'female'), ('Jeraldine', 'female'), ('Phedra', 'female'), ('Isobel', 'female'), ('Allegra', 'female'), ('Essy', 'female'), ('Roana', 'female'), ('Del', 'male'), ('Salmon', 'male'), ('Margery', 'female'), ('Reeba', 'female'), ('Maddy', 'male'), ('Debbie', 'female'), ('Garrett', 'male'), ('Ezra', 'male'), ('Karee', 'female'), ('Laurance', 'male'), ('Fletcher', 'male'), ('Wash', 'male'), ('Urson', 'male'), ('Riva', 'female'), ('Demetrius', 'male'), ('Marilu', 'male'), ('Obadias', 'male'), ('Lonny', 'male'), ('Federica', 'female'), ('Bruno', 'male'), ('Anne-Corinne', 'female'), ('Jerrie', 'female'), ('Terrie', 'female'), ('Sharon', 'female'), ('Sherill', 'female'), ('Ammamaria', 'female'), ('Goddard', 'male'), ('Fatima', 'female'), ('Marc', 'male'), ('Cassey', 'female'), ('Lorie', 'female'), ('Dorree', 'female'), ('Casi', 'female'), ('Freemon', 'male'), ('Cindra', 'female'), ('Dew', 'female'), ('Melantha', 'female'), ('Dodi', 'female'), ('Marthe', 'female'), ('Kellen', 'female'), ('Meier', 'male'), ('Flipper', 'male'), ('Zena', 'female'), ('Mable', 'female'), ('Cate', 'female'), ('Blair', 'female'), ('Marty', 'female'), ('Shalna', 'female'), ('Pacifica', 'female'), ('Hedwig', 'female'), ('Aram', 'male'), ('Rollins', 'male'), ('Francesmary', 'female'), ('Ingaborg', 'female'), ('Minetta', 'female'), ('Marcio', 'male'), ('Catarina', 'female'), ('Eudora', 'female'), ('Lanny', 'male'), ('Marylinda', 'female'), ('Maura', 'female'), ('Erica', 'female'), ('Len', 'male'), ('Ofelia', 'female'), ('Alvera', 'female'), ('Dorotea', 'female'), ('Taddeus', 'male'), ('Renato', 'male'), ('Max', 'female'), ('Eustace', 'male'), ('Pierette', 'female'), ('Carmine', 'female'), ('Winnah', 'female'), ('Rene', 'female'), ('Nichols', 'male'), ('Stormie', 'female'), ('Hortensia', 'female'), ('Drew', 'female'), ('Patin', 'male'), ('Feliza', 'female'), ('Leelah', 'female'), ('Elva', 'female'), ('Betti', 'female'), ('Phelia', 'female'), ('Adam', 'male'), ('Chev', 'male'), ('Elisabetta', 'female'), ('Tyne', 'female'), ('Rawley', 'male'), ('Bobby', 'male'), ('Clint', 'male'), ('Hill', 'male'), ('Claudia', 'female'), ('Regan', 'male'), ('Vivianne', 'female'), ('Coleen', 'female'), ('Dara', 'female'), ('Anneliese', 'female'), ('Dorelia', 'female'), ('Kyrstin', 'female'), ('Allin', 'male'), ('Martha', 'female'), ('Dimitri', 'male'), ('Marcie', 'female'), ('Jerold', ' ...

# %%
import random
random.shuffle(labeled_names)
featuresets = [(gender_features(n),gender) for(n,gender) in labeled_names]
train_set, test_set = featuresets[:5000], featuresets[-2000:]
print(len(train_set),len(test_set))
classifier = nltk.NaiveBayesClassifier.train(train_set)
classifier.classify(gender_features('David'))
classifier.classify(gender_features('Yann Lecun'))
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 5000 2000
# 0.7675

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/content/logs_dataset.csv")
print(df.head())
# Out:
#                     @timestamp                   _id  ip_address
# 0  July 8th 2019, 14:43:03.000  XswJ0msBoTGddM7vxMDB  10.1.1.285
# 1  July 8th 2019, 14:43:01.000  dKQJ0msB7mP0GwVzvJjz  10.1.2.389
# 2  July 8th 2019, 14:42:59.000  CcwJ0msBoTGddM7vtb8y  10.1.1.415
# 3  July 8th 2019, 14:42:57.000  bKQJ0msB7mP0GwVzrZdT   10.1.1.79
# 4  July 8th 2019, 14:42:55.000  L6QJ0msB7mP0GwVzpZeI   10.1.1.60

# %%
len(df)
# Out:
# 721547
